# %%
import polars as pl
import os

total_rows = 10091520

# Define the file path to your CSV file
csv_file_path = "/kaggle/input/leap-atmospheric-physics-ai-climsim/train.csv"

# Number of rows to read in each batch
batch_size = 1000000

# %%
import gc
gc.collect()
# Out:
# 11

# %%
# Create a CSV reader with the specified batch size
reader = pl.read_csv_batched(csv_file_path, batch_size=batch_size)

# %%
# 1,2
batches = reader.next_batches(2)

# %%
# 3
batches = reader.next_batches(1)

# %%
batches
# Out:
# [shape: (984_270, 925)
#  ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
#  │ sample_id ┆ state_t_0 ┆ state_t_1 ┆ state_t_2 ┆ … ┆ cam_out_S ┆ cam_out_S ┆ cam_out_S ┆ cam_out_ │
#  │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ OLS       ┆ OLL       ┆ OLSD      ┆ SOLLD    │
#  │ str       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
#  │           ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
#  ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
#  │ train_196 ┆ 225.36397 ┆ 230.97241 ┆ 248.31714 ┆ … ┆ 99.175852 ┆ 94.615056 ┆ 146.73759 ┆ 74.44112 │
#  │ 6821      ┆ 5         ┆ 6         ┆ 4         ┆   ┆           ┆           ┆ 6         ┆          │
#  │ train_196 ┆ 220.77966 ┆ 227.50879 ┆ 244.68688 ┆ … ┆ 150.36837 ┆ 268.24362 ┆ 104.15824 ┆ 37.41988 │
#  │ 6822      ┆ 8         ┆           ┆ 2         ┆   ┆ 2         ┆ 5         ┆ 7         ┆          │
#  │ train_196 ┆ 223.21302 ┆ 228.76063 ┆ 246.54331 ┆ … ┆ 90.227175 ┆ 98.665989 ┆ 146.11177 ┆ 88.14194 │
#  │ 6823      ┆ 1         ┆ 7         ┆ 9         ┆   ┆           ┆           ┆ 1         ┆ 9        │
#  │ train_196 ┆ 224.98910 ┆ 230.44990 ┆ 248.39221 ┆ … ┆ 15.425323 ┆ 12.46709  ┆ 128.89338 ┆ 70.32130 │
#  │ 6824      ┆ 4         ┆ 7         ┆ 3         ┆   ┆           ┆           ┆ 7         ┆ 5        │
#  │ train_196 ┆ 221.44050 ┆ 228.97104 ┆ 245.71794 ┆ … ┆ 27.526041 ┆ 30.616132 ┆ 53.490245 ┆ 35.39497 │
#  │ 6825      ┆ 2         ┆ 4         ┆ 4         ┆   ┆           ┆           ┆           ┆ 1        │
#  │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
#  │ train_295 ┆ 217.24852 ┆ 234.68938 ┆ 238.05508 ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 0.0      │
#  │ 1086      ┆ 5         ┆ 5         ┆ 2         ┆   ┆           ┆           ┆           ┆          │
#  │ train_295 ┆ 217.31996 ┆ 230.43201 ┆ 238.41266 ┆ … ┆ 29.49639  ┆ 47.233673 ┆ 25.999826 ┆ 6.821118 │
#  │ 1087      ┆ 8         ┆ 3         ┆ 4         ┆   ┆           ┆           ┆           ┆          │
#  │ train_295 ┆ 218.37507 ┆ 231.14567 ┆ 237.91365 ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 0.0      │
#  │ 1088      ┆ 7         ┆ 1         ┆ 7         ┆   ┆           ┆           ┆           ┆          │
#  │ train_295 ┆ 218.21786 ┆ 234.32797 ┆ 240.59109 ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 0.0      │
#  │ 1089      ┆ 3         ┆ 2         ┆ 7         ┆   ┆           ┆           ┆           ┆          │
#  │ train_295 ┆ 217.67664 ┆ 227.99759 ┆ 232.10526 ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 0.0      │
#  │ 1090      ┆ 2         ┆ 9         ┆ 1         ┆   ┆           ┆           ┆           ┆          │
#  └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘]

# %%
# Initialize a counter to track batches
batch_counter = 2


parquet_file_path = f'leap_train_batch_{batch_counter + 1}.parquet'
batches[0].write_parquet(parquet_file_path)
print(f'Batch {batch_counter + 1} saved to {parquet_file_path}')
# Out:
# Batch 3 saved to leap_train_batch_3.parquet

# %%
batches[0]
# Out:
# shape: (984_270, 925)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ sample_id ┆ state_t_0 ┆ state_t_1 ┆ state_t_2 ┆ … ┆ cam_out_S ┆ cam_out_S ┆ cam_out_S ┆ cam_out_ │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ OLS       ┆ OLL       ┆ OLSD      ┆ SOLLD    │
# │ str       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ train_196 ┆ 225.36397 ┆ 230.97241 ┆ 248.31714 ┆ … ┆ 99.175852 ┆ 94.615056 ┆ 146.73759 ┆ 74.44112 │
# │ 6821      ┆ 5         ┆ 6         ┆ 4         ┆   ┆           ┆           ┆ 6         ┆          │
# │ train_196 ┆ 220.77966 ┆ 227.50879 ┆ 244.68688 ┆ … ┆ 150.36837 ┆ 268.24362 ┆ 104.15824 ┆ 37.41988 │
# │ 6822      ┆ 8         ┆           ┆ 2         ┆   ┆ 2         ┆ 5         ┆ 7         ┆          │
# │ train_196 ┆ 223.21302 ┆ 228.76063 ┆ 246.54331 ┆ … ┆ 90.227175 ┆ 98.665989 ┆ 146.11177 ┆ 88.14194 │
# │ 6823      ┆ 1         ┆ 7         ┆ 9         ┆   ┆           ┆           ┆ 1         ┆ 9        │
# │ train_196 ┆ 224.98910 ┆ 230.44990 ┆ 248.39221 ┆ … ┆ 15.425323 ┆ 12.46709  ┆ 128.89338 ┆ 70.32130 │
# │ 6824      ┆ 4         ┆ 7         ┆ 3         ┆   ┆           ┆           ┆ 7         ┆ 5        │
# │ train_196 ┆ 221.44050 ┆ 228.97104 ┆ 245.71794 ┆ … ┆ 27.526041 ┆ 30.616132 ┆ 53.490245 ┆ 35.39497 │
# │ 6825      ┆ 2         ┆ 4         ┆ 4         ┆   ┆           ┆           ┆           ┆ 1        │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ train_295 ┆ 217.24852 ┆ 234.68938 ┆ 238.05508 ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 0.0      │
# │ 1086      ┆ 5         ┆ 5         ┆ 2         ┆   ┆           ┆           ┆           ┆          │
# │ train_295 ┆ 217.31996 ┆ 230.43201 ┆ 238.41266 ┆ … ┆ 29.49639  ┆ 47.233673 ┆ 25.999826 ┆ 6.821118 │
# │ 1087      ┆ 8         ┆ 3         ┆ 4         ┆   ┆           ┆           ┆           ┆          │
# │ train_295 ┆ 218.37507 ┆ 231.14567 ┆ 237.91365 ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 0.0      │
# │ 1088      ┆ 7         ┆ 1         ┆ 7         ┆   ┆           ┆           ┆           ┆          │
# │ train_295 ┆ 218.21786 ┆ 234.32797 ┆ 240.59109 ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 0.0      │
# │ 1089      ┆ 3         ┆ 2         ┆ 7         ┆   ┆           ┆           ┆           ┆          │
# │ train_295 ┆ 217.67664 ┆ 227.99759 ┆ 232.10526 ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 0.0      │
# │ 1090      ┆ 2         ┆ 9         ┆ 1         ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
